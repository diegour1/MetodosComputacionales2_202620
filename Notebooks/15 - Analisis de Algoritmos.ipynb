# %% [markdown]
# # Análisis de Algoritmos, Big O Notation
# Métodos Computacionales 2

# %% [markdown]
# ## Polynomial Complexity
#
# An algorithm has Polynomial complexity if its time increases with the size of the problem by the equation,
# $$
# O(n^x)
# $$

# %% [markdown]
# **Example:** Matrix multiplication
# Given $A = A_{i,j} \in \mathbb{R}^{n\times n}$ and $B_{j,k} \in \mathbb{R}^{n\times n}$ the product $C = AB$ is given by,
# $$
# C_{i, k} = \sum_{j=1}^{n}A_{i,j}B_{j,k}
# $$
# The summation has to be done $n$ times, for each $i$ and $k$ which run from $1$ to $n$, hence the complexity is given by,
# $$
# O(n^3)
# $$

# %%
import time
import numpy as np

# %%
def matrix_multiplication(A, B, C):
    n = len(A)
    m = len(A[0])
    p = len(B[0])
    for i in range(n):
        for j in range(m):
            for k in range(p):
                C[i, k] += A[i, j]*B[j, k]
    return C

# %%
times = []
for n in [64, 128, 256, 512]:
    A = np.random.randint(10, size=(n, n))
    B = np.random.randint(10, size=(n, n))
    C = np.random.randint(10, size=(n, n))
    time_initial = time.time()
    matrix_multiplication(A, B, C)
    print(time.time() - time_initial)
    times.append(float(time.time() - time_initial))
    
print(times)
# Out:
# 0.1692054271697998
# 1.3447928428649902
# 12.07370901107788
# 95.59883904457092
# [0.16937947273254395, 1.3456296920776367, 12.074613809585571, 95.60012412071228]

# %%
times[3]/times[2], times[2]/times[1], times[1]/times[0]
# Out:
# (7.917447765063842, 8.973207027664875, 7.944467357047643)

# %% [markdown]
# ## Logarithmic Complexity
#
# An algorithm has Logarithmic complexity if its time increases with the size of the problem by the equation,
#
# $$
# O(\log(n))
# $$
#
# This complexity is optimal.

# %% [markdown]
# **Example:** Given a number find the number of steps to obtain a number less than 1 by iteratively dividing by 2.
#
# $$
# 2 / 2 = 1, \quad 1 \text{ step}, \quad \log(2) = 1 \\
# 4 / 2 / 2 = 1, \quad  2 \text{ steps},  \quad \log(4) = 1  \\
# 16 / 2 / 2 / 2 / 2 = 1, \quad 4 \text{ steps}, \quad \log(16) = 4 \\
# $$

# %%
def num_steps(number):
  steps = 0
  num_temp = number
  while num_temp >= 1:
    num_temp = num_temp / 2
    steps += 1
  return steps

# %%
times = []
for number in [2**10, 2**100, 2**1000, 2*10000, 2*100000]:
    time_initial = time.time()
    num_steps(number)
    print(time.time() - time_initial)
    times.append(time.time() - time_initial)

print(times)
# Out:
# 6.67572021484375e-06
# 1.7881393432617188e-05
# 0.0001461505889892578
# 3.5762786865234375e-06
# 3.5762786865234375e-06
# [0.0002949237823486328, 4.673004150390625e-05, 0.00018978118896484375, 3.123283386230469e-05, 2.8848648071289062e-05]

# %%
times[4]/times[3], times[3]/times[2], times[2]/times[1], times[1]/times[0]
# Out:
# (1.651006711409396, 0.4644960166262556, 1.3459207459207458, 0.5607843137254902)

# %% [markdown]
# ## Dinamical programming

# %%
import numpy as np
def fibonnaci_dinamical(n):
    din_ar = np.zeros(n)
    din_ar[0], din_ar[1] = 1, 1
    for i in range(2, n):
        din_ar[i] = din_ar[i-1] + din_ar[i-2]
    return din_ar[n-1]

# %%
print(fibonnaci_dinamical(100))
# Out:
# 3.54224848179262e+20

# %%
def fibonacci(n):
    if n == 1:
        return 1
    if n == 2:
        return 1
    return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(35) # 100 does not run
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ad22a5e8437e> in <cell line: 1>()
# ----> 1 fibonacci(100)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       4     if n == 2:
#       5         return 1
# ----> 6     return fibonacci(n-1) + fibonacci(n-2)
#
# <ipython-input-11-34a403b50ae1> in fibonacci(n)
#       1 def fibonacci(n):
# ----> 2     if n == 1:
#       3         return 1
#       4     if n == 2:
#       5         return 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Sorting Algorithms

# %% [markdown]
# ### Selection Sort (Brute Force)

# %%
def selection_sort(list_unsorted):
  n = len(list_unsorted)
  min = 100000
  for i in range(0, n - 1):
    min = i
    for j in range(i+1, n):
      if list_unsorted[j] < list_unsorted[min]:
        min = j
    if min != i:
      a = list_unsorted[i]
      b = list_unsorted[min]
      list_unsorted[min] = a
      list_unsorted[i] = b
      
  return list_unsorted

unsorted_list = np.array([4, 1, 5, 7, 2, 6, 1, 1, 6, 4, 10, 33, 5, 7, 23])
print(selection_sort(unsorted_list))
# Out:
# [ 1  1  1  2  4  4  5  5  6  6  7  7 10 23 33]
